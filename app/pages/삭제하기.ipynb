# %%
# Jupyter Notebook 전용 코드
import pandas as pd
from pathlib import Path
import os

# 1. __file__ 대신 현재 작업 경로(os.getcwd)를 사용하거나 절대 경로를 직접 입력
# 방법 A: 절대 경로 직접 입력 (가장 확실)
project_root = Path("/Users/kimjiwoo/Documents/SKN23-2nd-3Team")

# 방법 B: 현재 노트북 파일 위치 기준으로 찾기 (노트북이 app 폴더 안에 있다면)
# current_dir = Path(os.getcwd())
# project_root = current_dir.parent  # 상황에 맞게 .parent 개수 조절

# 2. 데이터 경로 설정
DATA_PATH = project_root / "data" / "processed" / "features_ml_clean.parquet"

print(f"📂 경로 확인: {DATA_PATH}")

# 3. 로드 테스트
if DATA_PATH.exists():
    df = pd.read_parquet(DATA_PATH)
    print("✅ 데이터 로드 성공!")
    display(df.head()) # Jupyter에서는 display() 사용
else:
    print("❌ 파일을 찾을 수 없습니다.")
# Out:
# 📂 경로 확인: /Users/kimjiwoo/Documents/SKN23-2nd-3Team/data/processed/features_ml_clean.parquet
# ✅ 데이터 로드 성공!
#      user_id anchor_time  n_events_30d  active_days_30d  n_purchase_30d  \
# 0  113868975  2020-01-31            17                8               0
# 1  113868975  2020-02-29             6                5               0
# 2  113868975  2020-03-31             2                2               0
# 3  177507559  2019-12-31             4                1               1
# 4  178740206  2020-02-29             2                2               0
#
#    purchase_ratio  days_since_last_event  days_since_last_purchase  \
# 0            0.00               0.446910                 31.000000
# 1            0.00               3.373669                 31.000000
# 2            0.00              23.379780                 31.000000
# 3            0.25              26.808588                 26.808831
# 4            0.00              13.254109                 31.000000
#
# ...

# %%
df[df['anchor_time'].dt.month == 3]
# Out:
#           user_id anchor_time  n_events_30d  active_days_30d  n_purchase_30d  \
# 2       113868975  2020-03-31             2                2               0
# 22      273568916  2020-03-31             1                1               0
# 43      299358698  2020-03-31             6                1               0
# 75      322630864  2020-03-31             2                1               0
# 79      327023582  2020-03-31             1                1               0
# ...           ...         ...           ...              ...             ...
# 813534  635003998  2020-03-31             0                0               0
# 813535  635006916  2020-03-31             0                0               0
# 813536  635008176  2020-03-31             0                0               0
# 813537  635010251  2020-03-31             0                0               0
# 813538  635015432  2020-03-31             0                0               0
#
# ...

# %%
df['n_events_30d'].describe()
# Out:
# count    813540.000000
# mean          4.171958
# std           8.131964
# min           0.000000
# 25%           1.000000
# 50%           2.000000
# 75%           4.000000
# max        1824.000000
# Name: n_events_30d, dtype: float64

# %%
df['active_days_30d'].describe()
# Out:
# count    813540.000000
# mean          1.376622
# std           1.090506
# min           0.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max          30.000000
# Name: active_days_30d, dtype: float64

# %%
# 확인완
df['n_purchase_30d'].describe()
# Out:
# count    813540.000000
# mean          0.828440
# std           4.257849
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max         512.000000
# Name: n_purchase_30d, dtype: float64

# %%
df['purchase_ratio'].describe() # 확인완
# Out:
# count    813540.000000
# mean          0.015323
# std           0.043584
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: purchase_ratio, dtype: float64

# %%
df['days_since_last_event'].describe()
# Out:
# count    813540.000000
# mean          9.233939
# std           7.899547
# min           0.000000
# 25%           2.535749
# 50%           7.218993
# 75%          13.888134
# max          31.000000
# Name: days_since_last_event, dtype: float64

# %%
df['days_since_last_purchase'].describe()
# Out:
# count    813540.000000
# mean         26.788742
# std           8.724339
# min           0.000046
# 25%          31.000000
# 50%          31.000000
# 75%          31.000000
# max          31.000000
# Name: days_since_last_purchase, dtype: float64

# %%
df['brand_concentration_ratio'].describe()
# Out:
# count    813540.000000
# mean          0.931030
# std           0.182285
# min           0.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max           1.000000
# Name: brand_concentration_ratio, dtype: float64

# %%
df['brand_switch_count_30d'].describe()
# Out:
# count    813540.000000
# mean          0.156160
# std           1.253074
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max         616.000000
# Name: brand_switch_count_30d, dtype: float64

# %%
df['total_spend_30d'].describe()
# Out:
# count    813540.000000
# mean         39.334346
# std         313.066811
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max       68559.010000
# Name: total_spend_30d, dtype: float64

# %%
df['activity_ratio_15d'].describe()
# Out:
# count    813540.000000
# mean          0.507904
# std           0.480933
# min           0.000000
# 25%           0.000000
# 50%           0.500000
# 75%           1.000000
# max           1.000000
# Name: activity_ratio_15d, dtype: float64

# %%
df['price_volatility'].describe()
# Out:
# count    813540.000000
# mean          0.544813
# std           7.633177
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max         552.094833
# Name: price_volatility, dtype: float64

# %%
df['n_events_7d'].describe()
# Out:
# count    813540.000000
# mean          0.831358
# std           3.003381
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max         311.000000
# Name: n_events_7d, dtype: float64

# %%
df['visit_regularity'].describe()
# Out:
# count    813540.000000
# mean         -0.030780
# std           1.963886
# min          -1.000000
# 25%          -1.000000
# 50%          -1.000000
# 75%           0.001137
# max          20.887820
# Name: visit_regularity, dtype: float64

# %%
df['activity_trend'].describe()
# Out:
# count    813540.000000
# mean          0.205327
# std           0.388268
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: activity_trend, dtype: float64
